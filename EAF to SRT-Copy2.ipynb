# %%
# Imports

import pympi
import re
from collections import defaultdict
import shutil

# %%
# Utils

def get_all_time_offsets(eaf_file):
    
    offsets = []
    eaf = pympi.Elan.Eaf(eaf_file)    

    for media_descriptor in eaf.media_descriptors:
        TIME_ORIGIN='TIME_ORIGIN'
        if (TIME_ORIGIN in media_descriptor):
            offsets.append(int((media_descriptor['TIME_ORIGIN'])))
    
    return offsets if offsets else None


def format_time(seconds, offset=0):
    """Helper function to format time in SRT format (HH:MM:SS,ms)"""
    seconds += offset / 1000  # Convert milliseconds to seconds
    hours = int(seconds // 3600)
    minutes = int((seconds % 3600) // 60)
    whole_seconds = int(seconds % 60)
    milliseconds = int((seconds % 1) * 1000)  
    return f"{hours:02}:{minutes:02}:{whole_seconds:02},{milliseconds:03}"


def get_tier_names(eaf_filename):    
    try:
        # Load the EAF file
        eaf = pympi.Elan.Eaf(eaf_filename)
        
        # Get tier names
        tier_names = eaf.get_tier_names()
        
        return tier_names
    
    except Exception as e:
        print(f"Error reading EAF file: {str(e)}")
        return []

    
def printable_time(start_time, end_time):
    seconds = end_time-start_time
    if (seconds < 60):
        return f"{seconds:.0f} seconds"
    else:
        minutes = seconds/60.0
        return  f"{minutes:.2f} minutes"

# %%
def replace_pronoun(annotation, sentence, pronoun_gloss, replacement_options):
    # e.g. "PT:PRO1SG" is replaced by "I" or "me" depending
    # which is present in the main sentence
    gloss_present = None 
    if ("PT:"+pronoun_gloss) in annotation: 
        gloss_present = "PT:"+pronoun_gloss
    elif pronoun_gloss in annotation: 
        gloss_present = pronoun_gloss
    
    if gloss_present is not None:
        replacement_to_use = replacement_options[0]
        for replacement in replacement_options:
            if replacement in sentence:
                replacement_to_use = replacement
                break
        return annotation.replace(gloss_present, replacement)
    return annotation
    

def format_annotation(annotation, sentence):
    # Use regex to find and replace ADD-TO-SIGNBANK(...) wrapper
    pattern = r'ADD-TO-SIGNBANK\((.*?)\)'    
    def replacement(match):
        return match.group(1).strip()
    annotation = re.sub(pattern, replacement, annotation)
    
    # Replace pronouns with more english translations
    # Personal Pronouns:
    
    annotation = replace_pronoun(annotation, sentence, "PRO1SG", ["I", "me"])

    annotation = replace_pronoun(annotation, sentence, "PRO1SG", ["I","me"])
    annotation = replace_pronoun(annotation, sentence, "PRO2SG", ["you",])
    annotation = replace_pronoun(annotation, sentence, "PRO3SG", ["he","she","it"])
    annotation = replace_pronoun(annotation, sentence, "PRO1PL", ["we","us"])
    annotation = replace_pronoun(annotation, sentence, "PRO2PL", ["you(pl)",])
    annotation = replace_pronoun(annotation, sentence, "PRO3PL", ["they/them",])

    annotation = replace_pronoun(annotation, sentence, "POSS1SG", ["my","mine",])
    annotation = replace_pronoun(annotation, sentence, "POSS2SG", ["your","yours",])
    annotation = replace_pronoun(annotation, sentence, "POSS3SG", ["his","her","it"])
    annotation = replace_pronoun(annotation, sentence, "POSS1PL", ["our","ours",])
    annotation = replace_pronoun(annotation, sentence, "POSS2PL", ["your","yours",])
    annotation = replace_pronoun(annotation, sentence, "POSS3PL", ["their","theirs",])

    annotation = replace_pronoun(annotation, sentence, "BODY",["(points to body)",]) #  Point to a body part
    annotation = replace_pronoun(annotation, sentence, "LBUOY",["(points to list)",]) # Point to a list buoy
    annotation = replace_pronoun(annotation, sentence, "FBUOY",["(points to fragment)",]) # Point to a fragment buoy
    annotation = replace_pronoun(annotation, sentence, "BUOY",["(points)",]) # Point to a buoy (of unspecified type)*
    annotation = replace_pronoun(annotation, sentence, "PT:", ["(points)",])

   # annotation = annotation.replace("LBUOY-ONE", "(list)")
   # annotation = annotation.replace("LBUOY-TWO", "(list)")
   # annotation = annotation.replace("LBUOY-THREE", "(list)")

#    if "BUOY" in annotation:
 #       print(annotation)
    

    # Remove number suffixes
    annotation = re.sub(r'\d+$', '', annotation)
   
    return annotation 

def process_bsl(lh_gloss, rh_gloss, sentence):
#     if ("G:" in lh_gloss):
#         print(lh_gloss)
#     if ("G:" in rh_gloss):
#         print(rh_gloss)
    lh_gloss = lh_gloss.strip()
    rh_gloss = rh_gloss.strip()
    
    lh_gloss = format_annotation(lh_gloss, sentence)
    rh_gloss = format_annotation(rh_gloss, sentence)
    print(sentence)
    combined = ""
    if (lh_gloss == rh_gloss):
        combined = lh_gloss
    elif lh_gloss and rh_gloss:
        combined = lh_gloss + " | " + rh_gloss
    elif lh_gloss:
        combined = lh_gloss
    elif rh_gloss:
        combined = rh_gloss
    
    print(combined)
    return combined

# %%
def eaf_to_srt_combined(eaf_file, srt_file, offset):
    eaf = pympi.Elan.Eaf(eaf_file)
    
    # Collect all annotations from RH and LH tiers
    bsl_annotations = []
    en_annotations = []
    
    for tier_name in ['RH-IDgloss', 'LH-IDgloss']:
        for annotation in eaf.get_annotation_data_for_tier(tier_name):
            bsl_annotations.append({
                'tier': tier_name,
                'start': annotation[0],
                'end': annotation[1],
                'text': annotation[2]
            })
    
    for tier_name in ['Free Translation',]:
        for annotation in eaf.get_annotation_data_for_tier(tier_name):
            en_annotations.append({
                'tier': tier_name,
                'start': annotation[0],
                'end': annotation[1],
                'text': annotation[2]
            })
    
    # Sort annotations by start time
    en_annotations.sort(key=lambda x: x['start'])
    bsl_annotations.sort(key=lambda x: x['start'])
    
    # Combine L and R BSL annotations, with reference to english translation
    merged_annotations = []
    for en_ann in en_annotations:
        overlapping_bsl = [bsl_ann for bsl_ann in bsl_annotations 
                           if bsl_ann['start'] < en_ann['end'] and bsl_ann['end'] > en_ann['start']]
        
        current_annotation = None
        for bsl_ann in overlapping_bsl:
            if bsl_ann['tier'] == 'RH-IDgloss':
                rh_gloss = bsl_ann['text']
                lh_gloss = next((ann['text'] for ann in overlapping_bsl 
                                 if ann['tier'] == 'LH-IDgloss' and ann['start'] == bsl_ann['start']), '')
            else:
                lh_gloss = bsl_ann['text']
                rh_gloss = next((ann['text'] for ann in overlapping_bsl 
                                 if ann['tier'] == 'RH-IDgloss' and ann['start'] == bsl_ann['start']), '')
            
            if current_annotation is None or (lh_gloss, rh_gloss) != (current_annotation['lh_gloss'], current_annotation['rh_gloss']):
                if current_annotation:
                    merged_annotations.append(current_annotation)
                    
                current_annotation = {
                    'start': bsl_ann['start'],
                    'end': bsl_ann['end'],
                    'en_text': en_ann['text'],
                    'lh_gloss': lh_gloss,
                    'rh_gloss': rh_gloss
                }
            else:
                current_annotation['end'] = max(current_annotation['end'], bsl_ann['end'])
        
        if current_annotation:
            merged_annotations.append(current_annotation)
    
    
    # Remove duplicates
    unique_annotations = []
    for ann in merged_annotations:
        if not unique_annotations or (ann['lh_gloss'], ann['rh_gloss']) != unique_annotations[-1]:
            if unique_annotations:
                print(ann, unique_annotations[-1])
            unique_annotations.append(ann)
            
    # Write to SRT file
    with open(srt_file, 'w', encoding='utf-8') as f:
        for index, ann in enumerate(unique_annotations, 1):
            start_time = ann['start'] / 1000
            end_time = ann['end'] / 1000
            
            f.write(f"{index}\n")
            f.write(f"{format_time(start_time, offset)} --> {format_time(end_time, offset)}\n")
            parsed_bsl = process_bsl(ann['lh_gloss'], ann['rh_gloss'], ann['en_text'])
            f.write(f"{parsed_bsl}\n\n")
    
    print(f"Created SRT file: {srt_file}")

    
def process_file(eaf_file):

    srt_file_bsl = eaf_file.replace(".eaf", ".bsl.srt")
    srt_file_en = eaf_file.replace(".eaf", ".en.srt")

    tiers = get_tier_names(eaf_file)
    offsets = get_all_time_offsets(eaf_file)
    if (offsets is None):
        offset = 0
    elif (len(offsets)>1):
        offset = offsets[0]
    else:
        offset = offsets[0]

    print("Using time offset: "+str(offset))

    print("Extracting BSL subtitles")
    eaf_to_srt_combined(eaf_file, srt_file_bsl, offset)

process_file('inputs/BF10n.eaf')
# Out:
# Using time offset: 2960
# Extracting BSL subtitles
# {'start': 163, 'end': 598, 'en_text': 'Okay?', 'lh_gloss': '', 'rh_gloss': 'G:HEY'} {'start': 14, 'end': 159, 'en_text': 'Okay?', 'lh_gloss': '', 'rh_gloss': 'GOOD'}
# {'start': 1206, 'end': 1394, 'en_text': 'Right, hey.', 'lh_gloss': '', 'rh_gloss': 'G:HEY'} {'start': 163, 'end': 598, 'en_text': 'Okay?', 'lh_gloss': '', 'rh_gloss': 'G:HEY'}
# {'start': 1403, 'end': 1620, 'en_text': 'Right, hey.', 'lh_gloss': '', 'rh_gloss': 'GOOD'} {'start': 1206, 'end': 1394, 'en_text': 'Right, hey.', 'lh_gloss': '', 'rh_gloss': 'G:HEY'}
# {'start': 1629, 'end': 1916, 'en_text': 'Right, hey.', 'lh_gloss': '', 'rh_gloss': 'PT:PRO1SG'} {'start': 1403, 'end': 1620, 'en_text': 'Right, hey.', 'lh_gloss': '', 'rh_gloss': 'GOOD'}
# {'start': 1927, 'end': 2278, 'en_text': 'Right, hey.', 'lh_gloss': '', 'rh_gloss': 'G:HEY'} {'start': 1629, 'end': 1916, 'en_text': 'Right, hey.', 'lh_gloss': '', 'rh_gloss': 'PT:PRO1SG'}
# {'start': 2285, 'end': 2883, 'en_text': 'Right, hey.', 'lh_gloss': '', 'rh_gloss': 'PT:PRO1SG'} {'start': 1927, 'end': 2278, 'en_text': 'Right, hey.', 'lh_gloss': '', 'rh_gloss': 'G:HEY'}
# {'start': 2658, 'end': 3641, 'en_text': 'I was pregnant, expecting.', 'lh_gloss': '', 'rh_gloss': 'PT:PRO1SG'} {'start': 2285, 'end': 2883, 'en_text': 'Right, hey.', 'lh_gloss': '', 'rh_gloss': 'PT:PRO1SG'}
# {'start': 3658, 'end': 4677, 'en_text': 'I was pregnant, expecting.', 'lh_gloss': 'PREGNANT', 'rh_gloss': 'EXPECT'} {'start': 2658, 'end': 3641, 'en_text': 'I was pregnant, expecting.', 'lh_gloss': '', 'rh_gloss': 'PT:PRO1SG'}
# {'start': 4684, 'end': 5792, 'en_text': 'I gave birth to a baby boy.', 'lh_gloss': 'BORN', 'rh_gloss': 'BORN'} {'start': 3658, 'end': 4677, 'en_text': 'I was pregnant, expecting.', 'lh_gloss': 'PREGNANT', 'rh_gloss': 'EXPECT'}
# {'start': 5803, 'end': 6079, 'en_text': 'I gave birth to a baby boy.', 'lh_gloss': 'AT-LAST', 'rh_gloss': 'AT-LAST'} {'start': 4684, 'end': 5792, 'en_text': 'I gave birth to a baby boy.', 'lh_gloss': 'BORN', 'rh_gloss': 'BORN'}
# {'start': 6096, 'end': 6757, 'en_text': 'I gave birth to a baby boy.', 'lh_gloss': 'BABY', 'rh_gloss': 'BABY'} {'start': 5803, 'end': 6079, 'en_text': 'I gave birth to a baby boy.', 'lh_gloss': 'AT-LAST', 'rh_gloss': 'AT-LAST'}
# {'start': 6775, 'end': 7992, 'en_text': 'I gave birth to a baby boy.', 'lh_gloss': '', 'rh_gloss': 'BOY02'} {'start': 6096, 'end': 6757, 'en_text': 'I gave birth to a baby boy.', 'lh_gloss': 'BABY', 'rh_gloss': 'BABY'}
# {'start': 8009, 'end': 8433, 'en_text': 'I gave birth to a baby boy.', 'lh_gloss': 'ADD-TO-SIGNBANK(AND02)', 'rh_gloss': 'ADD-TO-SIGNBANK(AND02)'} {'start': 6775, 'end': 7992, 'en_text': 'I gave birth to a baby boy.', 'lh_gloss': '', 'rh_gloss': 'BOY02'}
# {'start': 8009, 'end': 8433, 'en_text': 'He grew and grew.', 'lh_gloss': 'ADD-TO-SIGNBANK(AND02)', 'rh_gloss': 'ADD-TO-SIGNBANK(AND02)'} {'start': 8009, 'end': 8433, 'en_text': 'I gave birth to a baby boy.', 'lh_gloss': 'ADD-TO-SIGNBANK(AND02)', 'rh_gloss': 'ADD-TO-SIGNBANK(AND02)'}
# {'start': 8450, 'end': 9727, 'en_text': 'He grew and grew.', 'lh_gloss': '?EXPAND', 'rh_gloss': '?EXPAND'} {'start': 8009, 'end': 8433, 'en_text': 'He grew and grew.', 'lh_gloss': 'ADD-TO-SIGNBANK(AND02)', 'rh_gloss': 'ADD-TO-SIGNBANK(AND02)'}
# {'start': 9744, 'end': 11600, 'en_text': 'He grew and grew.', 'lh_gloss': 'FS:MID^SPOUSE', 'rh_gloss': 'FS:MID^SPOUSE'} {'start': 8450, 'end': 9727, 'en_text': 'He grew and grew.', 'lh_gloss': '?EXPAND', 'rh_gloss': '?EXPAND'}
# {'start': 9744, 'end': 11600, 'en_text': 'The mid-wife would visit me at home.', 'lh_gloss': 'FS:MID^SPOUSE', 'rh_gloss': 'FS:MID^SPOUSE'} {'start': 9744, 'end': 11600, 'en_text': 'He grew and grew.', 'lh_gloss': 'FS:MID^SPOUSE', 'rh_gloss': 'FS:MID^SPOUSE'}
# {'start': 11610, 'end': 13122, 'en_text': 'The mid-wife would visit me at home.', 'lh_gloss': 'VISIT02', 'rh_gloss': 'VISIT02'} {'start': 9744, 'end': 11600, 'en_text': 'The mid-wife would visit me at home.', 'lh_gloss': 'FS:MID^SPOUSE', 'rh_gloss': 'FS:MID^SPOUSE'}
# {'start': 13137, 'end': 13802, 'en_text': 'The mid-wife would visit me at home.', 'lh_gloss': 'HOUSE02', 'rh_gloss': 'HOUSE02'} {'start': 11610, 'end': 13122, 'en_text': 'The mid-wife would visit me at home.', 'lh_gloss': 'VISIT02', 'rh_gloss': 'VISIT02'}
# {'start': 13816, 'end': 14438, 'en_text': 'That was to check the baby was alright, eating well etc. ', 'lh_gloss': '', 'rh_gloss': 'WHY'} {'start': 13137, 'end': 13802, 'en_text': 'The mid-wife would visit me at home.', 'lh_gloss': 'HOUSE02', 'rh_gloss': 'HOUSE02'}
# {'start': 14456, 'end': 15048, 'en_text': 'That was to check the baby was alright, eating well etc. ', 'lh_gloss': '', 'rh_gloss': 'CHECK'} {'start': 13816, 'end': 14438, 'en_text': 'That was to check the baby was alright, eating well etc. ', 'lh_gloss': '', 'rh_gloss': 'WHY'}
# {'start': 14461, 'end': 15043, 'en_text': 'That was to check the baby was alright, eating well etc. ', 'lh_gloss': 'CHECK', 'rh_gloss': ''} {'start': 14456, 'end': 15048, 'en_text': 'That was to check the baby was alright, eating well etc. ', 'lh_gloss': '', 'rh_gloss': 'CHECK'}
# {'start': 15052, 'end': 15839, 'en_text': 'That was to check the baby was alright, eating well etc. ', 'lh_gloss': '', 'rh_gloss': 'BABY'} {'start': 14461, 'end': 15043, 'en_text': 'That was to check the baby was alright, eating well etc. ', 'lh_gloss': 'CHECK', 'rh_gloss': ''}
# {'start': 15062, 'end': 15839, 'en_text': 'That was to check the baby was alright, eating well etc. ', 'lh_gloss': 'BABY', 'rh_gloss': ''} {'start': 15052, 'end': 15839, 'en_text': 'That was to check the baby was alright, eating well etc. ', 'lh_gloss': '', 'rh_gloss': 'BABY'}
# {'start': 15858, 'end': 16601, 'en_text': 'That was to check the baby was alright, eating well etc. ', 'lh_gloss': 'ALRIGHT', 'rh_gloss': 'ALRIGHT'} {'start': 15062, 'end': 15839, 'en_text': 'That was to check the baby was alright, eating well etc. ', 'lh_gloss': 'BABY', 'rh_gloss': ''}
# {'start': 16616, 'end': 17676, 'en_text': 'That was to check the baby was alright, eating well etc. ', 'lh_gloss': '', 'rh_gloss': 'EAT'} {'start': 15858, 'end': 16601, 'en_text': 'That was to check the baby was alright, eating well etc. ', 'lh_gloss': 'ALRIGHT', 'rh_gloss': 'ALRIGHT'}
# {'start': 17692, 'end': 17994, 'en_text': 'That was to check the baby was alright, eating well etc. ', 'lh_gloss': 'KNOW', 'rh_gloss': 'KNOW'} {'start': 16616, 'end': 17676, 'en_text': 'That was to check the baby was alright, eating well etc. ', 'lh_gloss': '', 'rh_gloss': 'EAT'}
# {'start': 18014, 'end': 18461, 'en_text': 'That was to check the baby was alright, eating well etc. ', 'lh_gloss': 'LBUOY-ONE', 'rh_gloss': 'PT:LBUOY'} {'start': 17692, 'end': 17994, 'en_text': 'That was to check the baby was alright, eating well etc. ', 'lh_gloss': 'KNOW', 'rh_gloss': 'KNOW'}
# {'start': 18472, 'end': 19036, 'en_text': 'That was to check the baby was alright, eating well etc. ', 'lh_gloss': 'LBUOY-FIVE', 'rh_gloss': 'PT:LBUOY'} {'start': 18014, 'end': 18461, 'en_text': 'That was to check the baby was alright, eating well etc. ', 'lh_gloss': 'LBUOY-ONE', 'rh_gloss': 'PT:LBUOY'}
# {'start': 19053, 'end': 19399, 'en_text': 'That was to check the baby was alright, eating well etc. ', 'lh_gloss': 'PT:PRO1SG', 'rh_gloss': 'PT:PRO1SG'} {'start': 18472, 'end': 19036, 'en_text': 'That was to check the baby was alright, eating well etc. ', 'lh_gloss': 'LBUOY-FIVE', 'rh_gloss': 'PT:LBUOY'}
# {'start': 19053, 'end': 19399, 'en_text': 'I was patient.', 'lh_gloss': 'PT:PRO1SG', 'rh_gloss': 'PT:PRO1SG'} {'start': 19053, 'end': 19399, 'en_text': 'That was to check the baby was alright, eating well etc. ', 'lh_gloss': 'PT:PRO1SG', 'rh_gloss': 'PT:PRO1SG'}
# {'start': 19411, 'end': 20009, 'en_text': 'I was patient.', 'lh_gloss': 'BEHAVIOUR', 'rh_gloss': 'BEHAVIOUR'} {'start': 19053, 'end': 19399, 'en_text': 'I was patient.', 'lh_gloss': 'PT:PRO1SG', 'rh_gloss': 'PT:PRO1SG'}
# {'start': 20021, 'end': 20564, 'en_text': 'I was patient.', 'lh_gloss': '', 'rh_gloss': 'AGAIN'} {'start': 19411, 'end': 20009, 'en_text': 'I was patient.', 'lh_gloss': 'BEHAVIOUR', 'rh_gloss': 'BEHAVIOUR'}
# {'start': 20021, 'end': 20564, 'en_text': 'They came again the next week.\t', 'lh_gloss': '', 'rh_gloss': 'AGAIN'} {'start': 20021, 'end': 20564, 'en_text': 'I was patient.', 'lh_gloss': '', 'rh_gloss': 'AGAIN'}
# {'start': 20578, 'end': 21081, 'en_text': 'They came again the next week.\t', 'lh_gloss': '', 'rh_gloss': 'COME'} {'start': 20021, 'end': 20564, 'en_text': 'They came again the next week.\t', 'lh_gloss': '', 'rh_gloss': 'AGAIN'}
# {'start': 21091, 'end': 21963, 'en_text': 'They came again the next week.\t', 'lh_gloss': 'NEXT-WEEK02', 'rh_gloss': 'NEXT-WEEK02'} {'start': 20578, 'end': 21081, 'en_text': 'They came again the next week.\t', 'lh_gloss': '', 'rh_gloss': 'COME'}
# {'start': 21981, 'end': 22239, 'en_text': 'They came again the next week.\t', 'lh_gloss': 'PT:PRO1SG', 'rh_gloss': 'PT:PRO1SG'} {'start': 21091, 'end': 21963, 'en_text': 'They came again the next week.\t', 'lh_gloss': 'NEXT-WEEK02', 'rh_gloss': 'NEXT-WEEK02'}
# {'start': 21981, 'end': 22239, 'en_text': 'Very frustrating.', 'lh_gloss': 'PT:PRO1SG', 'rh_gloss': 'PT:PRO1SG'} {'start': 21981, 'end': 22239, 'en_text': 'They came again the next week.\t', 'lh_gloss': 'PT:PRO1SG', 'rh_gloss': 'PT:PRO1SG'}
# {'start': 22247, 'end': 23038, 'en_text': 'Very frustrating.', 'lh_gloss': 'STRESS', 'rh_gloss': 'STRESS'} {'start': 21981, 'end': 22239, 'en_text': 'Very frustrating.', 'lh_gloss': 'PT:PRO1SG', 'rh_gloss': 'PT:PRO1SG'}
# {'start': 23053, 'end': 23677, 'en_text': 'Very frustrating.', 'lh_gloss': '', 'rh_gloss': 'COME'} {'start': 22247, 'end': 23038, 'en_text': 'Very frustrating.', 'lh_gloss': 'STRESS', 'rh_gloss': 'STRESS'}
# {'start': 23053, 'end': 24355, 'en_text': 'They came again and again.', 'lh_gloss': '', 'rh_gloss': 'COME'} {'start': 23053, 'end': 23677, 'en_text': 'Very frustrating.', 'lh_gloss': '', 'rh_gloss': 'COME'}
# {'start': 24368, 'end': 25238, 'en_text': 'They came again and again.', 'lh_gloss': 'ADD-TO-SIGNBANK(AND02)', 'rh_gloss': 'ADD-TO-SIGNBANK(AND02)'} {'start': 23053, 'end': 24355, 'en_text': 'They came again and again.', 'lh_gloss': '', 'rh_gloss': 'COME'}
# {'start': 24368, 'end': 25238, 'en_text': 'After a while, they stopped.', 'lh_gloss': 'ADD-TO-SIGNBANK(AND02)', 'rh_gloss': 'ADD-TO-SIGNBANK(AND02)'} {'start': 24368, 'end': 25238, 'en_text': 'They came again and again.', 'lh_gloss': 'ADD-TO-SIGNBANK(AND02)', 'rh_gloss': 'ADD-TO-SIGNBANK(AND02)'}
# {'start': 25257, 'end': 26287, 'en_text': 'After a while, they stopped.', 'lh_gloss': '?LATER', 'rh_gloss': '?LATER'} {'start': 24368, 'end': 25238, 'en_text': 'After a while, they stopped.', 'lh_gloss': 'ADD-TO-SIGNBANK(AND02)', 'rh_gloss': 'ADD-TO-SIGNBANK(AND02)'}
# {'start': 26303, 'end': 27238, 'en_text': 'After a while, they stopped.', 'lh_gloss': 'FINISH03', 'rh_gloss': 'FINISH03'} {'start': 25257, 'end': 26287, 'en_text': 'After a while, they stopped.', 'lh_gloss': '?LATER', 'rh_gloss': '?LATER'}
# {'start': 27253, 'end': 27952, 'en_text': 'Now, with the baby bigger, I would take them to another place, like a hospital. ', 'lh_gloss': 'NOW', 'rh_gloss': 'NOW'} {'start': 26303, 'end': 27238, 'en_text': 'After a while, they stopped.', 'lh_gloss': 'FINISH03', 'rh_gloss': 'FINISH03'}
# {'start': 27975, 'end': 28401, 'en_text': 'Now, with the baby bigger, I would take them to another place, like a hospital. ', 'lh_gloss': '', 'rh_gloss': 'PT:PRO1SG'} {'start': 27253, 'end': 27952, 'en_text': 'Now, with the baby bigger, I would take them to another place, like a hospital. ', 'lh_gloss': 'NOW', 'rh_gloss': 'NOW'}
# {'start': 28411, 'end': 28876, 'en_text': 'Now, with the baby bigger, I would take them to another place, like a hospital. ', 'lh_gloss': 'BABY', 'rh_gloss': 'BABY'} {'start': 27975, 'end': 28401, 'en_text': 'Now, with the baby bigger, I would take them to another place, like a hospital. ', 'lh_gloss': '', 'rh_gloss': 'PT:PRO1SG'}
# {'start': 28891, 'end': 29367, 'en_text': 'Now, with the baby bigger, I would take them to another place, like a hospital. ', 'lh_gloss': '?EXPAND', 'rh_gloss': '?EXPAND'} {'start': 28411, 'end': 28876, 'en_text': 'Now, with the baby bigger, I would take them to another place, like a hospital. ', 'lh_gloss': 'BABY', 'rh_gloss': 'BABY'}
# {'start': 29377, 'end': 29485, 'en_text': 'Now, with the baby bigger, I would take them to another place, like a hospital. ', 'lh_gloss': 'MUST', 'rh_gloss': 'MUST'} {'start': 28891, 'end': 29367, 'en_text': 'Now, with the baby bigger, I would take them to another place, like a hospital. ', 'lh_gloss': '?EXPAND', 'rh_gloss': '?EXPAND'}
# {'start': 29505, 'end': 29688, 'en_text': 'Now, with the baby bigger, I would take them to another place, like a hospital. ', 'lh_gloss': 'PT:LOC/PT:PRO3SG', 'rh_gloss': 'PT:PRO1SG'} {'start': 29377, 'end': 29485, 'en_text': 'Now, with the baby bigger, I would take them to another place, like a hospital. ', 'lh_gloss': 'MUST', 'rh_gloss': 'MUST'}
# {'start': 29694, 'end': 31007, 'en_text': 'Now, with the baby bigger, I would take them to another place, like a hospital. ', 'lh_gloss': '?PT:', 'rh_gloss': 'FROM-TO'} {'start': 29505, 'end': 29688, 'en_text': 'Now, with the baby bigger, I would take them to another place, like a hospital. ', 'lh_gloss': 'PT:LOC/PT:PRO3SG', 'rh_gloss': 'PT:PRO1SG'}
# {'start': 31021, 'end': 31878, 'en_text': 'Now, with the baby bigger, I would take them to another place, like a hospital. ', 'lh_gloss': 'SAME', 'rh_gloss': 'SAME'} {'start': 29694, 'end': 31007, 'en_text': 'Now, with the baby bigger, I would take them to another place, like a hospital. ', 'lh_gloss': '?PT:', 'rh_gloss': 'FROM-TO'}
# {'start': 31889, 'end': 32765, 'en_text': 'Now, with the baby bigger, I would take them to another place, like a hospital. ', 'lh_gloss': 'ADD-TO-SIGNBANK(HOSPITAL5)', 'rh_gloss': 'ADD-TO-SIGNBANK(HOSPITAL5)'} {'start': 31021, 'end': 31878, 'en_text': 'Now, with the baby bigger, I would take them to another place, like a hospital. ', 'lh_gloss': 'SAME', 'rh_gloss': 'SAME'}
# {'start': 32776, 'end': 33519, 'en_text': 'They checked its weight and other things.', 'lh_gloss': 'CHECK', 'rh_gloss': 'CHECK'} {'start': 31889, 'end': 32765, 'en_text': 'Now, with the baby bigger, I would take them to another place, like a hospital. ', 'lh_gloss': 'ADD-TO-SIGNBANK(HOSPITAL5)', 'rh_gloss': 'ADD-TO-SIGNBANK(HOSPITAL5)'}
# {'start': 33534, 'end': 34552, 'en_text': 'They checked its weight and other things.', 'lh_gloss': 'SCALES', 'rh_gloss': 'SCALES'} {'start': 32776, 'end': 33519, 'en_text': 'They checked its weight and other things.', 'lh_gloss': 'CHECK', 'rh_gloss': 'CHECK'}
# {'start': 34565, 'end': 34975, 'en_text': 'They checked its weight and other things.', 'lh_gloss': 'LBUOY-ONE', 'rh_gloss': 'PT:LBUOY'} {'start': 33534, 'end': 34552, 'en_text': 'They checked its weight and other things.', 'lh_gloss': 'SCALES', 'rh_gloss': 'SCALES'}
# {'start': 34990, 'end': 35712, 'en_text': 'They checked its weight and other things.', 'lh_gloss': 'LBUOY-FIVE', 'rh_gloss': 'PT:LBUOY'} {'start': 34565, 'end': 34975, 'en_text': 'They checked its weight and other things.', 'lh_gloss': 'LBUOY-ONE', 'rh_gloss': 'PT:LBUOY'}
# {'start': 35727, 'end': 35957, 'en_text': 'Fine.', 'lh_gloss': 'PT:PRO1SG', 'rh_gloss': 'PT:PRO1SG'} {'start': 34990, 'end': 35712, 'en_text': 'They checked its weight and other things.', 'lh_gloss': 'LBUOY-FIVE', 'rh_gloss': 'PT:LBUOY'}
# {'start': 35974, 'end': 36663, 'en_text': 'Fine.', 'lh_gloss': 'GOOD', 'rh_gloss': 'GOOD'} {'start': 35727, 'end': 35957, 'en_text': 'Fine.', 'lh_gloss': 'PT:PRO1SG', 'rh_gloss': 'PT:PRO1SG'}
# {'start': 36672, 'end': 37297, 'en_text': 'Fine.', 'lh_gloss': 'ADD-TO-SIGNBANK(AND02)', 'rh_gloss': 'ADD-TO-SIGNBANK(AND02)'} {'start': 35974, 'end': 36663, 'en_text': 'Fine.', 'lh_gloss': 'GOOD', 'rh_gloss': 'GOOD'}
# {'start': 36672, 'end': 37297, 'en_text': 'Later on, a friend gave me a big pram.', 'lh_gloss': 'ADD-TO-SIGNBANK(AND02)', 'rh_gloss': 'ADD-TO-SIGNBANK(AND02)'} {'start': 36672, 'end': 37297, 'en_text': 'Fine.', 'lh_gloss': 'ADD-TO-SIGNBANK(AND02)', 'rh_gloss': 'ADD-TO-SIGNBANK(AND02)'}
# {'start': 37318, 'end': 38202, 'en_text': 'Later on, a friend gave me a big pram.', 'lh_gloss': 'LATER', 'rh_gloss': 'LATER'} {'start': 36672, 'end': 37297, 'en_text': 'Later on, a friend gave me a big pram.', 'lh_gloss': 'ADD-TO-SIGNBANK(AND02)', 'rh_gloss': 'ADD-TO-SIGNBANK(AND02)'}
# {'start': 38219, 'end': 38439, 'en_text': 'Later on, a friend gave me a big pram.', 'lh_gloss': 'PT:POSS1SG', 'rh_gloss': 'PT:POSS1SG'} {'start': 37318, 'end': 38202, 'en_text': 'Later on, a friend gave me a big pram.', 'lh_gloss': 'LATER', 'rh_gloss': 'LATER'}
# {'start': 38447, 'end': 39159, 'en_text': 'Later on, a friend gave me a big pram.', 'lh_gloss': 'FRIEND', 'rh_gloss': 'FRIEND'} {'start': 38219, 'end': 38439, 'en_text': 'Later on, a friend gave me a big pram.', 'lh_gloss': 'PT:POSS1SG', 'rh_gloss': 'PT:POSS1SG'}
# {'start': 39176, 'end': 39914, 'en_text': 'Later on, a friend gave me a big pram.', 'lh_gloss': 'GIVE', 'rh_gloss': 'GIVE'} {'start': 38447, 'end': 39159, 'en_text': 'Later on, a friend gave me a big pram.', 'lh_gloss': 'FRIEND', 'rh_gloss': 'FRIEND'}
# {'start': 39937, 'end': 41195, 'en_text': 'Later on, a friend gave me a big pram.', 'lh_gloss': 'MOW', 'rh_gloss': 'MOW'} {'start': 39176, 'end': 39914, 'en_text': 'Later on, a friend gave me a big pram.', 'lh_gloss': 'GIVE', 'rh_gloss': 'GIVE'}
# {'start': 41221, 'end': 41838, 'en_text': 'Later on, a friend gave me a big pram.', 'lh_gloss': 'BIG', 'rh_gloss': 'BIG'} {'start': 39937, 'end': 41195, 'en_text': 'Later on, a friend gave me a big pram.', 'lh_gloss': 'MOW', 'rh_gloss': 'MOW'}
# {'start': 41854, 'end': 42229, 'en_text': 'Later on, a friend gave me a big pram.', 'lh_gloss': 'PT:PRO1SG', 'rh_gloss': 'PT:PRO1SG'} {'start': 41221, 'end': 41838, 'en_text': 'Later on, a friend gave me a big pram.', 'lh_gloss': 'BIG', 'rh_gloss': 'BIG'}
# {'start': 41854, 'end': 42229, 'en_text': 'I was delighted they had given it to me.', 'lh_gloss': 'PT:PRO1SG', 'rh_gloss': 'PT:PRO1SG'} {'start': 41854, 'end': 42229, 'en_text': 'Later on, a friend gave me a big pram.', 'lh_gloss': 'PT:PRO1SG', 'rh_gloss': 'PT:PRO1SG'}
# {'start': 42240, 'end': 42635, 'en_text': 'I was delighted they had given it to me.', 'lh_gloss': 'ADD-TO-SIGNBANK(EXCITED2)', 'rh_gloss': 'ADD-TO-SIGNBANK(EXCITED2)'} {'start': 41854, 'end': 42229, 'en_text': 'I was delighted they had given it to me.', 'lh_gloss': 'PT:PRO1SG', 'rh_gloss': 'PT:PRO1SG'}
# {'start': 42651, 'end': 43352, 'en_text': 'I was delighted they had given it to me.', 'lh_gloss': 'GIVE', 'rh_gloss': 'GIVE'} {'start': 42240, 'end': 42635, 'en_text': 'I was delighted they had given it to me.', 'lh_gloss': 'ADD-TO-SIGNBANK(EXCITED2)', 'rh_gloss': 'ADD-TO-SIGNBANK(EXCITED2)'}
# {'start': 43369, 'end': 44151, 'en_text': 'I was delighted they had given it to me.', 'lh_gloss': 'ADD-TO-SIGNBANK(EXCITED2)', 'rh_gloss': 'ADD-TO-SIGNBANK(EXCITED2)'} {'start': 42651, 'end': 43352, 'en_text': 'I was delighted they had given it to me.', 'lh_gloss': 'GIVE', 'rh_gloss': 'GIVE'}
# {'start': 44166, 'end': 45130, 'en_text': 'I thanked them a lot.', 'lh_gloss': 'THANK', 'rh_gloss': 'THANK'} {'start': 43369, 'end': 44151, 'en_text': 'I was delighted they had given it to me.', 'lh_gloss': 'ADD-TO-SIGNBANK(EXCITED2)', 'rh_gloss': 'ADD-TO-SIGNBANK(EXCITED2)'}
# {'start': 45144, 'end': 45423, 'en_text': 'I thanked them a lot.', 'lh_gloss': '?FRIEND/ADD-TO-SIGNBANK(AND02)', 'rh_gloss': '?FRIEND/ADD-TO-SIGNBANK(AND02)'} {'start': 44166, 'end': 45130, 'en_text': 'I thanked them a lot.', 'lh_gloss': 'THANK', 'rh_gloss': 'THANK'}
# {'start': 45144, 'end': 45423, 'en_text': 'After they left, I lifted the baby into the pram.', 'lh_gloss': '?FRIEND/ADD-TO-SIGNBANK(AND02)', 'rh_gloss': '?FRIEND/ADD-TO-SIGNBANK(AND02)'} {'start': 45144, 'end': 45423, 'en_text': 'I thanked them a lot.', 'lh_gloss': '?FRIEND/ADD-TO-SIGNBANK(AND02)', 'rh_gloss': '?FRIEND/ADD-TO-SIGNBANK(AND02)'}
# {'start': 45437, 'end': 46117, 'en_text': 'After they left, I lifted the baby into the pram.', 'lh_gloss': 'GO', 'rh_gloss': ''} {'start': 45144, 'end': 45423, 'en_text': 'After they left, I lifted the baby into the pram.', 'lh_gloss': '?FRIEND/ADD-TO-SIGNBANK(AND02)', 'rh_gloss': '?FRIEND/ADD-TO-SIGNBANK(AND02)'}
# {'start': 46132, 'end': 46336, 'en_text': 'After they left, I lifted the baby into the pram.', 'lh_gloss': '', 'rh_gloss': 'PT:PRO1SG'} {'start': 45437, 'end': 46117, 'en_text': 'After they left, I lifted the baby into the pram.', 'lh_gloss': 'GO', 'rh_gloss': ''}
# {'start': 46353, 'end': 46396, 'en_text': 'After they left, I lifted the baby into the pram.', 'lh_gloss': 'HUG', 'rh_gloss': 'HUG'} {'start': 46132, 'end': 46336, 'en_text': 'After they left, I lifted the baby into the pram.', 'lh_gloss': '', 'rh_gloss': 'PT:PRO1SG'}
# {'start': 46404, 'end': 47125, 'en_text': 'After they left, I lifted the baby into the pram.', 'lh_gloss': 'BABY', 'rh_gloss': 'BABY'} {'start': 46353, 'end': 46396, 'en_text': 'After they left, I lifted the baby into the pram.', 'lh_gloss': 'HUG', 'rh_gloss': 'HUG'}
# {'start': 47141, 'end': 47858, 'en_text': 'After they left, I lifted the baby into the pram.', 'lh_gloss': 'DSH(SPHERE)-MOVE/G:CA:PICKING-BABY-UP', 'rh_gloss': 'DSH(SPHERE)-MOVE/G:CA:PICKING-BABY-UP'} {'start': 46404, 'end': 47125, 'en_text': 'After they left, I lifted the baby into the pram.', 'lh_gloss': 'BABY', 'rh_gloss': 'BABY'}
# {'start': 47867, 'end': 48352, 'en_text': 'After they left, I lifted the baby into the pram.', 'lh_gloss': 'DSH(SPHERE)-MOVE/G:CA:PLACES-BABY-DOWN', 'rh_gloss': 'DSH(SPHERE)-MOVE/G:CA:PLACES-BABY-DOWN'} {'start': 47141, 'end': 47858, 'en_text': 'After they left, I lifted the baby into the pram.', 'lh_gloss': 'DSH(SPHERE)-MOVE/G:CA:PICKING-BABY-UP', 'rh_gloss': 'DSH(SPHERE)-MOVE/G:CA:PICKING-BABY-UP'}
# {'start': 47867, 'end': 48352, 'en_text': 'It was sprung, really old fashioned, with a hood over it.', 'lh_gloss': 'DSH(SPHERE)-MOVE/G:CA:PLACES-BABY-DOWN', 'rh_gloss': 'DSH(SPHERE)-MOVE/G:CA:PLACES-BABY-DOWN'} {'start': 47867, 'end': 48352, 'en_text': 'After they left, I lifted the baby into the pram.', 'lh_gloss': 'DSH(SPHERE)-MOVE/G:CA:PLACES-BABY-DOWN', 'rh_gloss': 'DSH(SPHERE)-MOVE/G:CA:PLACES-BABY-DOWN'}
# {'start': 48361, 'end': 49322, 'en_text': 'It was sprung, really old fashioned, with a hood over it.', 'lh_gloss': 'DSH(FIST)-MOVE/G:CA:MOVES-PRAM-UP-AND-DOWN', 'rh_gloss': 'DSH(FIST)-MOVE/G:CA:MOVES-PRAM-UP-AND-DOWN'} {'start': 47867, 'end': 48352, 'en_text': 'It was sprung, really old fashioned, with a hood over it.', 'lh_gloss': 'DSH(SPHERE)-MOVE/G:CA:PLACES-BABY-DOWN', 'rh_gloss': 'DSH(SPHERE)-MOVE/G:CA:PLACES-BABY-DOWN'}
# {'start': 49326, 'end': 50472, 'en_text': 'It was sprung, really old fashioned, with a hood over it.', 'lh_gloss': '', 'rh_gloss': 'OLD^FASHIONED02'} {'start': 48361, 'end': 49322, 'en_text': 'It was sprung, really old fashioned, with a hood over it.', 'lh_gloss': 'DSH(FIST)-MOVE/G:CA:MOVES-PRAM-UP-AND-DOWN', 'rh_gloss': 'DSH(FIST)-MOVE/G:CA:MOVES-PRAM-UP-AND-DOWN'}
# {'start': 49334, 'end': 50473, 'en_text': 'It was sprung, really old fashioned, with a hood over it.', 'lh_gloss': 'OLD^FASHIONED2 ', 'rh_gloss': ''} {'start': 49326, 'end': 50472, 'en_text': 'It was sprung, really old fashioned, with a hood over it.', 'lh_gloss': '', 'rh_gloss': 'OLD^FASHIONED02'}
# {'start': 50484, 'end': 51323, 'en_text': 'It was sprung, really old fashioned, with a hood over it.', 'lh_gloss': 'DSS(SPHERE)', 'rh_gloss': 'DSS(SPHERE)'} {'start': 49334, 'end': 50473, 'en_text': 'It was sprung, really old fashioned, with a hood over it.', 'lh_gloss': 'OLD^FASHIONED2 ', 'rh_gloss': ''}
# {'start': 51338, 'end': 52075, 'en_text': 'It was sprung, really old fashioned, with a hood over it.', 'lh_gloss': 'ADD-TO-SIGNBANK(UNKNOWN)', 'rh_gloss': 'ADD-TO-SIGNBANK(UNKNOWN)'} {'start': 50484, 'end': 51323, 'en_text': 'It was sprung, really old fashioned, with a hood over it.', 'lh_gloss': 'DSS(SPHERE)', 'rh_gloss': 'DSS(SPHERE)'}
# {'start': 52088, 'end': 52268, 'en_text': 'It was sprung, really old fashioned, with a hood over it.', 'lh_gloss': 'PT:PRO1SG', 'rh_gloss': 'PT:PRO1SG'} {'start': 51338, 'end': 52075, 'en_text': 'It was sprung, really old fashioned, with a hood over it.', 'lh_gloss': 'ADD-TO-SIGNBANK(UNKNOWN)', 'rh_gloss': 'ADD-TO-SIGNBANK(UNKNOWN)'}
# {'start': 52281, 'end': 53202, 'en_text': 'I pushed it along, to visit the mid-wife at the hospital.', 'lh_gloss': 'DSH(FIST)-MOVE/G:CA-MOVES-PRAM-UP-AND-DOWN', 'rh_gloss': 'DSH(FIST)-MOVE/G:CA:MOVES-PRAM-UP-AND-DOWN'} {'start': 52088, 'end': 52268, 'en_text': 'It was sprung, really old fashioned, with a hood over it.', 'lh_gloss': 'PT:PRO1SG', 'rh_gloss': 'PT:PRO1SG'}
# {'start': 53215, 'end': 53476, 'en_text': 'I pushed it along, to visit the mid-wife at the hospital.', 'lh_gloss': 'FEEL', 'rh_gloss': 'FEEL'} {'start': 52281, 'end': 53202, 'en_text': 'I pushed it along, to visit the mid-wife at the hospital.', 'lh_gloss': 'DSH(FIST)-MOVE/G:CA-MOVES-PRAM-UP-AND-DOWN', 'rh_gloss': 'DSH(FIST)-MOVE/G:CA:MOVES-PRAM-UP-AND-DOWN'}
# {'start': 53496, 'end': 54240, 'en_text': 'I pushed it along, to visit the mid-wife at the hospital.', 'lh_gloss': 'DSH(FIST)-MOVE/G:CA:MOVES-PRAM-UP-AND-DOWN', 'rh_gloss': 'DSH(FIST)-MOVE/G:CA:MOVES-PRAM-UP-AND-DOWN'} {'start': 53215, 'end': 53476, 'en_text': 'I pushed it along, to visit the mid-wife at the hospital.', 'lh_gloss': 'FEEL', 'rh_gloss': 'FEEL'}
# {'start': 54255, 'end': 54800, 'en_text': 'I pushed it along, to visit the mid-wife at the hospital.', 'lh_gloss': '', 'rh_gloss': 'VISIT02'} {'start': 53496, 'end': 54240, 'en_text': 'I pushed it along, to visit the mid-wife at the hospital.', 'lh_gloss': 'DSH(FIST)-MOVE/G:CA:MOVES-PRAM-UP-AND-DOWN', 'rh_gloss': 'DSH(FIST)-MOVE/G:CA:MOVES-PRAM-UP-AND-DOWN'}
# {'start': 54813, 'end': 56235, 'en_text': 'I pushed it along, to visit the mid-wife at the hospital.', 'lh_gloss': 'FS:MID^SPOUSE', 'rh_gloss': 'FS:MID^SPOUSE'} {'start': 54255, 'end': 54800, 'en_text': 'I pushed it along, to visit the mid-wife at the hospital.', 'lh_gloss': '', 'rh_gloss': 'VISIT02'}
# {'start': 56247, 'end': 56353, 'en_text': 'I pushed it along, to visit the mid-wife at the hospital.', 'lh_gloss': '', 'rh_gloss': 'PT:LOC'} {'start': 54813, 'end': 56235, 'en_text': 'I pushed it along, to visit the mid-wife at the hospital.', 'lh_gloss': 'FS:MID^SPOUSE', 'rh_gloss': 'FS:MID^SPOUSE'}
# {'start': 56370, 'end': 56915, 'en_text': 'I pushed it along, to visit the mid-wife at the hospital.', 'lh_gloss': 'ADD-TO-SIGNBANK(HOSPITAL5)', 'rh_gloss': 'ADD-TO-SIGNBANK(HOSPITAL5)'} {'start': 56247, 'end': 56353, 'en_text': 'I pushed it along, to visit the mid-wife at the hospital.', 'lh_gloss': '', 'rh_gloss': 'PT:LOC'}
# {'start': 56921, 'end': 57085, 'en_text': 'I pushed it along, to visit the mid-wife at the hospital.', 'lh_gloss': 'FOR', 'rh_gloss': ''} {'start': 56370, 'end': 56915, 'en_text': 'I pushed it along, to visit the mid-wife at the hospital.', 'lh_gloss': 'ADD-TO-SIGNBANK(HOSPITAL5)', 'rh_gloss': 'ADD-TO-SIGNBANK(HOSPITAL5)'}
# {'start': 56921, 'end': 57085, 'en_text': 'The baby was to be weighed.', 'lh_gloss': 'FOR', 'rh_gloss': ''} {'start': 56921, 'end': 57085, 'en_text': 'I pushed it along, to visit the mid-wife at the hospital.', 'lh_gloss': 'FOR', 'rh_gloss': ''}
# {'start': 57079, 'end': 57485, 'en_text': 'The baby was to be weighed.', 'lh_gloss': '', 'rh_gloss': 'BABY'} {'start': 56921, 'end': 57085, 'en_text': 'The baby was to be weighed.', 'lh_gloss': 'FOR', 'rh_gloss': ''}
# {'start': 57085, 'end': 57485, 'en_text': 'The baby was to be weighed.', 'lh_gloss': 'BABY', 'rh_gloss': ''} {'start': 57079, 'end': 57485, 'en_text': 'The baby was to be weighed.', 'lh_gloss': '', 'rh_gloss': 'BABY'}
# {'start': 57495, 'end': 58072, 'en_text': 'The baby was to be weighed.', 'lh_gloss': 'SCALES', 'rh_gloss': ''} {'start': 57085, 'end': 57485, 'en_text': 'The baby was to be weighed.', 'lh_gloss': 'BABY', 'rh_gloss': ''}
# {'start': 57496, 'end': 58072, 'en_text': 'The baby was to be weighed.', 'lh_gloss': '', 'rh_gloss': 'SCALES'} {'start': 57495, 'end': 58072, 'en_text': 'The baby was to be weighed.', 'lh_gloss': 'SCALES', 'rh_gloss': ''}
# {'start': 58083, 'end': 58205, 'en_text': 'The baby was to be weighed.', 'lh_gloss': 'G:WELL', 'rh_gloss': ''} {'start': 57496, 'end': 58072, 'en_text': 'The baby was to be weighed.', 'lh_gloss': '', 'rh_gloss': 'SCALES'}
# {'start': 58084, 'end': 58205, 'en_text': 'The baby was to be weighed.', 'lh_gloss': '', 'rh_gloss': 'G:WELL'} {'start': 58083, 'end': 58205, 'en_text': 'The baby was to be weighed.', 'lh_gloss': 'G:WELL', 'rh_gloss': ''}
# {'start': 58218, 'end': 58634, 'en_text': 'The baby was to be weighed.', 'lh_gloss': '', 'rh_gloss': 'PT:PRO1SG'} {'start': 58084, 'end': 58205, 'en_text': 'The baby was to be weighed.', 'lh_gloss': '', 'rh_gloss': 'G:WELL'}
# {'start': 58218, 'end': 58634, 'en_text': 'I pushed the pram along.', 'lh_gloss': '', 'rh_gloss': 'PT:PRO1SG'} {'start': 58218, 'end': 58634, 'en_text': 'The baby was to be weighed.', 'lh_gloss': '', 'rh_gloss': 'PT:PRO1SG'}
# {'start': 58653, 'end': 60605, 'en_text': 'I pushed the pram along.', 'lh_gloss': 'DSH(FIST)-MOVE/G:CA:MOVES-PRAM-SLOWLY', 'rh_gloss': ''} {'start': 58218, 'end': 58634, 'en_text': 'I pushed the pram along.', 'lh_gloss': '', 'rh_gloss': 'PT:PRO1SG'}
# {'start': 58654, 'end': 60605, 'en_text': 'I pushed the pram along.', 'lh_gloss': '', 'rh_gloss': 'DSH(FIST)-MOVE/G:CA:MOVES-PRAM-SLOWLY'} {'start': 58653, 'end': 60605, 'en_text': 'I pushed the pram along.', 'lh_gloss': 'DSH(FIST)-MOVE/G:CA:MOVES-PRAM-SLOWLY', 'rh_gloss': ''}
# {'start': 58653, 'end': 60605, 'en_text': 'I got really hot.', 'lh_gloss': 'DSH(FIST)-MOVE/G:CA:MOVES-PRAM-SLOWLY', 'rh_gloss': ''} {'start': 58654, 'end': 60605, 'en_text': 'I pushed the pram along.', 'lh_gloss': '', 'rh_gloss': 'DSH(FIST)-MOVE/G:CA:MOVES-PRAM-SLOWLY'}
# {'start': 58654, 'end': 60605, 'en_text': 'I got really hot.', 'lh_gloss': '', 'rh_gloss': 'DSH(FIST)-MOVE/G:CA:MOVES-PRAM-SLOWLY'} {'start': 58653, 'end': 60605, 'en_text': 'I got really hot.', 'lh_gloss': 'DSH(FIST)-MOVE/G:CA:MOVES-PRAM-SLOWLY', 'rh_gloss': ''}
# {'start': 60616, 'end': 62117, 'en_text': 'I got really hot.', 'lh_gloss': 'HOT02', 'rh_gloss': ''} {'start': 58654, 'end': 60605, 'en_text': 'I got really hot.', 'lh_gloss': '', 'rh_gloss': 'DSH(FIST)-MOVE/G:CA:MOVES-PRAM-SLOWLY'}
# {'start': 60617, 'end': 62117, 'en_text': 'I got really hot.', 'lh_gloss': '', 'rh_gloss': 'HOT02'} {'start': 60616, 'end': 62117, 'en_text': 'I got really hot.', 'lh_gloss': 'HOT02', 'rh_gloss': ''}
# {'start': 62139, 'end': 62352, 'en_text': 'I carried on pushing and got sweaty.', 'lh_gloss': '', 'rh_gloss': 'PT:PRO1SG'} {'start': 60617, 'end': 62117, 'en_text': 'I got really hot.', 'lh_gloss': '', 'rh_gloss': 'HOT02'}
# {'start': 62371, 'end': 63006, 'en_text': 'I carried on pushing and got sweaty.', 'lh_gloss': 'DSH(FIST)-MOVE/G:CA:MOVES-PRAM-SLOWLY', 'rh_gloss': ''} {'start': 62139, 'end': 62352, 'en_text': 'I carried on pushing and got sweaty.', 'lh_gloss': '', 'rh_gloss': 'PT:PRO1SG'}
# {'start': 62372, 'end': 63006, 'en_text': 'I carried on pushing and got sweaty.', 'lh_gloss': '', 'rh_gloss': 'DSH(FIST)-MOVE/G:CA:MOVES-PRAM-SLOWLY'} {'start': 62371, 'end': 63006, 'en_text': 'I carried on pushing and got sweaty.', 'lh_gloss': 'DSH(FIST)-MOVE/G:CA:MOVES-PRAM-SLOWLY', 'rh_gloss': ''}
# {'start': 63023, 'end': 63437, 'en_text': 'I carried on pushing and got sweaty.', 'lh_gloss': '', 'rh_gloss': 'HOT'} {'start': 62372, 'end': 63006, 'en_text': 'I carried on pushing and got sweaty.', 'lh_gloss': '', 'rh_gloss': 'DSH(FIST)-MOVE/G:CA:MOVES-PRAM-SLOWLY'}
# {'start': 63451, 'end': 64713, 'en_text': 'I carried on pushing and got sweaty.', 'lh_gloss': 'G:CA:SWEATING-ON-FACE', 'rh_gloss': ''} {'start': 63023, 'end': 63437, 'en_text': 'I carried on pushing and got sweaty.', 'lh_gloss': '', 'rh_gloss': 'HOT'}
# {'start': 63453, 'end': 64713, 'en_text': 'I carried on pushing and got sweaty.', 'lh_gloss': '', 'rh_gloss': 'G:CA:SWEATING-ON-FACE'} {'start': 63451, 'end': 64713, 'en_text': 'I carried on pushing and got sweaty.', 'lh_gloss': 'G:CA:SWEATING-ON-FACE', 'rh_gloss': ''}
# {'start': 64730, 'end': 65761, 'en_text': 'I carried on pushing and got sweaty.', 'lh_gloss': 'G:CA:SHAKES-TOP-TO-COOL-DOWN', 'rh_gloss': 'G:CA:SHAKES-TOP-TO-COOL-DOWN'} {'start': 63453, 'end': 64713, 'en_text': 'I carried on pushing and got sweaty.', 'lh_gloss': '', 'rh_gloss': 'G:CA:SWEATING-ON-FACE'}
# {'start': 64730, 'end': 65761, 'en_text': 'I was really hot.', 'lh_gloss': 'G:CA:SHAKES-TOP-TO-COOL-DOWN', 'rh_gloss': 'G:CA:SHAKES-TOP-TO-COOL-DOWN'} {'start': 64730, 'end': 65761, 'en_text': 'I carried on pushing and got sweaty.', 'lh_gloss': 'G:CA:SHAKES-TOP-TO-COOL-DOWN', 'rh_gloss': 'G:CA:SHAKES-TOP-TO-COOL-DOWN'}
# {'start': 65781, 'end': 66313, 'en_text': 'People were walking past me shivering.', 'lh_gloss': '', 'rh_gloss': 'PEOPLE02'} {'start': 64730, 'end': 65761, 'en_text': 'I was really hot.', 'lh_gloss': 'G:CA:SHAKES-TOP-TO-COOL-DOWN', 'rh_gloss': 'G:CA:SHAKES-TOP-TO-COOL-DOWN'}
# {'start': 66331, 'end': 67003, 'en_text': 'People were walking past me shivering.', 'lh_gloss': 'WALK03', 'rh_gloss': ''} {'start': 65781, 'end': 66313, 'en_text': 'People were walking past me shivering.', 'lh_gloss': '', 'rh_gloss': 'PEOPLE02'}
# {'start': 66333, 'end': 67003, 'en_text': 'People were walking past me shivering.', 'lh_gloss': '', 'rh_gloss': 'WALK03'} {'start': 66331, 'end': 67003, 'en_text': 'People were walking past me shivering.', 'lh_gloss': 'WALK03', 'rh_gloss': ''}
# {'start': 67011, 'end': 68326, 'en_text': 'People were walking past me shivering.', 'lh_gloss': 'COLD', 'rh_gloss': ''} {'start': 66333, 'end': 67003, 'en_text': 'People were walking past me shivering.', 'lh_gloss': '', 'rh_gloss': 'WALK03'}
# {'start': 67012, 'end': 68326, 'en_text': 'People were walking past me shivering.', 'lh_gloss': '', 'rh_gloss': 'COLD'} {'start': 67011, 'end': 68326, 'en_text': 'People were walking past me shivering.', 'lh_gloss': 'COLD', 'rh_gloss': ''}
# {'start': 68335, 'end': 68509, 'en_text': 'People were walking past me shivering.', 'lh_gloss': '', 'rh_gloss': 'PT:PRO1SG'} {'start': 67012, 'end': 68326, 'en_text': 'People were walking past me shivering.', 'lh_gloss': '', 'rh_gloss': 'COLD'}
# {'start': 68525, 'end': 69081, 'en_text': 'People were walking past me shivering.', 'lh_gloss': '', 'rh_gloss': 'DSEW(1-VERT)-MOVE:HUMAN'} {'start': 68335, 'end': 68509, 'en_text': 'People were walking past me shivering.', 'lh_gloss': '', 'rh_gloss': 'PT:PRO1SG'}
# {'start': 68525, 'end': 69081, 'en_text': 'What was happening?', 'lh_gloss': '', 'rh_gloss': 'DSEW(1-VERT)-MOVE:HUMAN'} {'start': 68525, 'end': 69081, 'en_text': 'People were walking past me shivering.', 'lh_gloss': '', 'rh_gloss': 'DSEW(1-VERT)-MOVE:HUMAN'}
# Okay?
# GOOD
# Okay?
# G:HEY
# Right, hey.
# G:HEY
# Right, hey.
# GOOD
# Right, hey.
# me
# Right, hey.
# G:HEY
# Right, hey.
# me
# I was pregnant, expecting.
# I
# I was pregnant, expecting.
# PREGNANT | EXPECT
# I gave birth to a baby boy.
# BORN
# I gave birth to a baby boy.
# AT-LAST
# I gave birth to a baby boy.
# BABY
# I gave birth to a baby boy.
# BOY
# I gave birth to a baby boy.
# AND
# He grew and grew.
# AND
# He grew and grew.
# ?EXPAND
# He grew and grew.
# FS:MID^SPOUSE
# The mid-wife would visit me at home.
# FS:MID^SPOUSE
# The mid-wife would visit me at home.
# VISIT
# The mid-wife would visit me at home.
# HOUSE
# That was to check the baby was alright, eating well etc.
# WHY
# That was to check the baby was alright, eating well etc.
# CHECK
# That was to check the baby was alright, eating well etc.
# CHECK
# That was to check the baby was alright, eating well etc.
# BABY
# That was to check the baby was alright, eating well etc.
# BABY
# That was to check the baby was alright, eating well etc.
# ALRIGHT
# That was to check the baby was alright, eating well etc.
# EAT
# That was to check the baby was alright, eating well etc.
# KNOW
# That was to check the baby was alright, eating well etc.
# (points to list)-ONE | (points to list)
# That was to check the baby was alright, eating well etc.
# (points to list)-FIVE | (points to list)
# That was to check the baby was alright, eating well etc.
# me
# I was patient.
# I
# I was patient.
# BEHAVIOUR
# I was patient.
# AGAIN
# They came again the next week.
# AGAIN
# They came again the next week.
# COME
# They came again the next week.
# NEXT-WEEK
# They came again the next week.
# me
# Very frustrating.
# me
# Very frustrating.
# STRESS
# Very frustrating.
# COME
# They came again and again.
# COME
# They came again and again.
# AND
# After a while, they stopped.
# AND
# After a while, they stopped.
# ?LATER
# After a while, they stopped.
# FINISH
# Now, with the baby bigger, I would take them to another place, like a hospital.
# NOW
# Now, with the baby bigger, I would take them to another place, like a hospital.
# I
# Now, with the baby bigger, I would take them to another place, like a hospital.
# BABY
# Now, with the baby bigger, I would take them to another place, like a hospital.
# ?EXPAND
# Now, with the baby bigger, I would take them to another place, like a hospital.
# MUST
# Now, with the baby bigger, I would take them to another place, like a hospital.
# (points)LOC/he | I
# Now, with the baby bigger, I would take them to another place, like a hospital.
# ?(points) | FROM-TO
# Now, with the baby bigger, I would take them to another place, like a hospital.
# SAME
# Now, with the baby bigger, I would take them to another place, like a hospital.
# HOSPITAL
# They checked its weight and other things.
# CHECK
# They checked its weight and other things.
# SCALES
# They checked its weight and other things.
# (points to list)-ONE | (points to list)
# They checked its weight and other things.
# (points to list)-FIVE | (points to list)
# Fine.
# me
# Fine.
# GOOD
# Fine.
# AND
# Later on, a friend gave me a big pram.
# AND
# Later on, a friend gave me a big pram.
# LATER
# Later on, a friend gave me a big pram.
# mine
# Later on, a friend gave me a big pram.
# FRIEND
# Later on, a friend gave me a big pram.
# GIVE
# Later on, a friend gave me a big pram.
# MOW
# Later on, a friend gave me a big pram.
# BIG
# Later on, a friend gave me a big pram.
# me
# I was delighted they had given it to me.
# I
# I was delighted they had given it to me.
# EXCITED
# I was delighted they had given it to me.
# GIVE
# I was delighted they had given it to me.
# EXCITED
# I thanked them a lot.
# THANK
# I thanked them a lot.
# ?FRIEND/AND
# After they left, I lifted the baby into the pram.
# ?FRIEND/AND
# After they left, I lifted the baby into the pram.
# GO
# After they left, I lifted the baby into the pram.
# I
# After they left, I lifted the baby into the pram.
# HUG
# After they left, I lifted the baby into the pram.
# BABY
# After they left, I lifted the baby into the pram.
# DSH(SPHERE)-MOVE/G:CA:PICKING-BABY-UP
# After they left, I lifted the baby into the pram.
# DSH(SPHERE)-MOVE/G:CA:PLACES-BABY-DOWN
# It was sprung, really old fashioned, with a hood over it.
# DSH(SPHERE)-MOVE/G:CA:PLACES-BABY-DOWN
# It was sprung, really old fashioned, with a hood over it.
# DSH(FIST)-MOVE/G:CA:MOVES-PRAM-UP-AND-DOWN
# It was sprung, really old fashioned, with a hood over it.
# OLD^FASHIONED
# It was sprung, really old fashioned, with a hood over it.
# OLD^FASHIONED
# It was sprung, really old fashioned, with a hood over it.
# DSS(SPHERE)
# It was sprung, really old fashioned, with a hood over it.
# UNKNOWN
# It was sprung, really old fashioned, with a hood over it.
# I
# I pushed it along, to visit the mid-wife at the hospital.
# DSH(FIST)-MOVE/G:CA-MOVES-PRAM-UP-AND-DOWN | DSH(FIST)-MOVE/G:CA:MOVES-PRAM-UP-AND-DOWN
# I pushed it along, to visit the mid-wife at the hospital.
# FEEL
# I pushed it along, to visit the mid-wife at the hospital.
# DSH(FIST)-MOVE/G:CA:MOVES-PRAM-UP-AND-DOWN
# I pushed it along, to visit the mid-wife at the hospital.
# VISIT
# I pushed it along, to visit the mid-wife at the hospital.
# FS:MID^SPOUSE
# I pushed it along, to visit the mid-wife at the hospital.
# (points)LOC
# I pushed it along, to visit the mid-wife at the hospital.
# HOSPITAL
# I pushed it along, to visit the mid-wife at the hospital.
# FOR
# The baby was to be weighed.
# FOR
# The baby was to be weighed.
# BABY
# The baby was to be weighed.
# BABY
# The baby was to be weighed.
# SCALES
# The baby was to be weighed.
# SCALES
# The baby was to be weighed.
# G:WELL
# The baby was to be weighed.
# G:WELL
# The baby was to be weighed.
# me
# I pushed the pram along.
# I
# I pushed the pram along.
# DSH(FIST)-MOVE/G:CA:MOVES-PRAM-SLOWLY
# I pushed the pram along.
# DSH(FIST)-MOVE/G:CA:MOVES-PRAM-SLOWLY
# I got really hot.
# DSH(FIST)-MOVE/G:CA:MOVES-PRAM-SLOWLY
# I got really hot.
# DSH(FIST)-MOVE/G:CA:MOVES-PRAM-SLOWLY
# I got really hot.
# HOT
# I got really hot.
# HOT
# I carried on pushing and got sweaty.
# I
# I carried on pushing and got sweaty.
# DSH(FIST)-MOVE/G:CA:MOVES-PRAM-SLOWLY
# I carried on pushing and got sweaty.
# DSH(FIST)-MOVE/G:CA:MOVES-PRAM-SLOWLY
# I carried on pushing and got sweaty.
# HOT
# I carried on pushing and got sweaty.
# G:CA:SWEATING-ON-FACE
# I carried on pushing and got sweaty.
# G:CA:SWEATING-ON-FACE
# I carried on pushing and got sweaty.
# G:CA:SHAKES-TOP-TO-COOL-DOWN
# I was really hot.
# G:CA:SHAKES-TOP-TO-COOL-DOWN
# People were walking past me shivering.
# PEOPLE
# People were walking past me shivering.
# WALK
# People were walking past me shivering.
# WALK
# People were walking past me shivering.
# COLD
# People were walking past me shivering.
# COLD
# People were walking past me shivering.
# me
# People were walking past me shivering.
# DSEW(1-VERT)-MOVE:HUMAN
# What was happening?
# DSEW(1-VERT)-MOVE:HUMAN
# Created SRT file: inputs/BF10n.bsl.srt

# %%
import glob, os

for file in glob.glob('inputs/*.eaf'):
    print("-"*16)
    print(file)
    process_file(file)
# Out:
# ----------------
# inputs/BF24n.eaf
# Using time offset: 4720
# Extracting english subtitles
# Found 5.80 minutes of subtitles from 00:00:04,723 to 00:05:52,610
# Extracting BSL subtitles
# Found 48 seconds of subtitles from 00:00:04,723 to 00:00:52,710
# ----------------
# inputs/BF12n.eaf
# Using time offset: 1635
# Extracting english subtitles
# Found 3.45 minutes of subtitles from 00:01:32,001 to 00:04:58,711
# Extracting BSL subtitles
# Found 2.48 minutes of subtitles from 00:00:01,696 to 00:02:30,742
# ----------------
# inputs/BF13n.eaf
# Using time offset: 18106
# Extracting english subtitles
# Found 5.48 minutes of subtitles from 00:01:55,972 to 00:07:25,046
# Extracting BSL subtitles
# Found 3.65 minutes of subtitles from 00:00:19,706 to 00:03:58,448
# ----------------
# inputs/BF25n.eaf
# Using time offset: 88
# Extracting english subtitles
# Found 3.85 minutes of subtitles from 00:00:01,598 to 00:03:52,567
# Extracting BSL subtitles
# LBUOY-TWO (points to list)
# Found 54 seconds of subtitles from 00:00:00,852 to 00:00:54,762
# ----------------
# inputs/BF14n.eaf
# Using time offset: 815
# Extracting english subtitles
# Found 3.06 minutes of subtitles from 00:00:02,556 to 00:03:06,340
# Extracting BSL subtitles
# (points to list) LBUOY-TWO
# (points to list) LBUOY-TWO
# Found 46 seconds of subtitles from 00:00:00,818 to 00:00:47,057
# ----------------
# inputs/BF18n.eaf
# Using time offset: 2226
# Extracting english subtitles
# Found 2.16 minutes of subtitles from 00:02:56,841 to 00:05:06,266
# Extracting BSL subtitles
# Found 56 seconds of subtitles from 00:02:56,841 to 00:03:53,237
# ----------------
# inputs/BF22n.eaf
# Using time offset: 515
# Extracting english subtitles
# Found 8.46 minutes of subtitles from 00:00:00,918 to 00:08:28,534
# Extracting BSL subtitles
# Found 4.87 minutes of subtitles from 00:00:00,918 to 00:04:53,110
# ----------------
# inputs/BF23n.eaf
# Using time offset: 10841
# Extracting english subtitles
# Found 4.19 minutes of subtitles from 00:01:40,916 to 00:05:52,081
# Extracting BSL subtitles
# LBUOY-TWO (points to list)
# LBUOY-THREE (points to list)
# LBUOY-TWO (points to list)
# LBUOY-FOUR (points to list)
# Found 3.41 minutes of subtitles from 00:01:10,796 to 00:04:35,625
# ----------------
# inputs/BF19n.eaf
# Using time offset: 5646
# Extracting english subtitles
# Found 2.76 minutes of subtitles from 00:00:06,625 to 00:02:52,495
# Extracting BSL subtitles
# Found 41 seconds of subtitles from 00:00:05,655 to 00:00:46,700
# ----------------
# inputs/BF15n.eaf
# Using time offset: 9810
# Extracting english subtitles
# Found 5.73 minutes of subtitles from 00:00:50,975 to 00:06:34,793
# Extracting BSL subtitles
# Found 3.60 minutes of subtitles from 00:00:11,358 to 00:03:47,311
# ----------------
# inputs/BF20n.eaf
# Using time offset: 9460
# Extracting english subtitles
# Found 1.48 minutes of subtitles from 00:01:57,122 to 00:03:26,034
# Extracting BSL subtitles
# Found 2.57 minutes of subtitles from 00:00:10,844 to 00:02:45,298
# ----------------
# inputs/BF21n.eaf
# Using time offset: 263
# Extracting english subtitles
# Found 8.65 minutes of subtitles from 00:00:01,333 to 00:08:40,173
# Extracting BSL subtitles
# PBUOY (points)LOC
# PBUOY WHICH
# Found 50 seconds of subtitles from 00:00:01,349 to 00:00:51,295
# ----------------
# inputs/BF17n.eaf
# Using time offset: 4990
# Extracting english subtitles
# Found 5.08 minutes of subtitles from 00:00:05,502 to 00:05:10,513
# Extracting BSL subtitles
# Found 35 seconds of subtitles from 00:00:05,250 to 00:00:39,795
# ----------------
# inputs/BF10n.eaf
# Using time offset: 2960
# Extracting english subtitles
# Found 2.26 minutes of subtitles from 00:00:02,960 to 00:02:18,597
# Extracting BSL subtitles
# LBUOY-ONE (points to list)
# LBUOY-FIVE (points to list)
# LBUOY-FIVE (points to list)
# LBUOY-ONE (points to list)
# LBUOY-FIVE (points to list)
# LBUOY-FIVE (points to list)
# Found 1.15 minutes of subtitles from 00:00:02,973 to 00:01:12,040
# ----------------
# inputs/BF11n.eaf
# Using time offset: 0
# Extracting english subtitles
# Found 1.46 minutes of subtitles from 00:00:02,217 to 00:01:29,832
# Extracting BSL subtitles
# Found 46 seconds of subtitles from 00:00:01,104 to 00:00:46,777
# ----------------
# inputs/BF1n.eaf
# Using time offset: 3661
# Extracting english subtitles
# Found 3.05 minutes of subtitles from 00:00:03,661 to 00:03:06,695
# Extracting BSL subtitles
# LBUOY-TWO (points to list)
# LBUOY-TWO (points to list)
# LBUOY-TWO (points to list)
# LBUOY-TWO (points to list)
# LBUOY-TWO (points to list)
# Found 36 seconds of subtitles from 00:00:03,661 to 00:00:39,402

# %%
# Example usage
annotations = [
    {'start': 1.0, 'end': 2.0, 'rh_text': 'Hello', 'lh_text': 'World'},
    {'start': 2.5, 'end': 3.5, 'rh_text': 'How', 'lh_text': 'are you?'},
    {'start': 5, 'end': 5.01, 'rh_text': 'wibble', 'lh_text': ''},
    {'start': 6.0, 'end': 7.0, 'rh_text': 'Good', 'lh_text': 'morning'}
]

extended_annotations = extend_annotations_with_priority(annotations)
for annotation in extended_annotations:
    print(annotation)
# Out:
# {'start': 0.8999999999999999, 'end': 2.45, 'rh_text': 'Hello', 'lh_text': 'World'}
# {'start': 2.45, 'end': 4.0, 'rh_text': 'How', 'lh_text': 'are you?'}
# {'start': 4.655, 'end': 5.755, 'rh_text': 'wibble', 'lh_text': ''}
# {'start': 5.9, 'end': 7.5, 'rh_text': 'Good', 'lh_text': 'morning'}

# %%
import re
from datetime import datetime, timedelta

def parse_srt(file_path):
    subtitles = []
    with open(file_path, 'r', encoding='utf-8') as file:
        lines = file.readlines()
        for i in range(0, len(lines), 4):
            if i + 2 < len(lines):
                time_range = lines[i + 1].strip()
                text = lines[i + 2].strip()
                start, end = time_range.split(' --> ')
                start_time = datetime.strptime(start, '%H:%M:%S,%f')
                end_time = datetime.strptime(end, '%H:%M:%S,%f')
                subtitles.append({
                    'start': start_time,
                    'end': end_time,
                    'text': text
                })
    return subtitles

def process_subtitles(english_srt, bsl_srt):
    english_subtitles = parse_srt(english_srt)
    bsl_subtitles = parse_srt(bsl_srt)
    
    output = []
    bsl_index = 0
    
    for english_sub in english_subtitles:
        output.append(f"- {english_sub['text']}")
        
        while bsl_index < len(bsl_subtitles):
            bsl_sub = bsl_subtitles[bsl_index]
            if bsl_sub['start'] < english_sub['end'] and bsl_sub['end'] > english_sub['start']:
                output.append(f"- {bsl_sub['text']}")
                bsl_index += 1
            else:
                break
    
    # Add any remaining BSL subtitles
    while bsl_index < len(bsl_subtitles):
        output.append(f"- {bsl_subtitles[bsl_index]['text']}")
        bsl_index += 1
    
    return '\n'.join(output)

# Usage
english_srt = 'inputs/BF1n.en.srt'
bsl_srt = 'inputs/BF1n.bsl.srt'
result = process_subtitles(english_srt, bsl_srt)
print(result)
# Out:
# - Are we ready?
# - GOOD
# - I want to tell you about my puppy.
# - I/me
# - EXPLAIN
# - ABOUT
# - my/mine
# - FS:PUPPY
# - DSEW(FLAT)-BE:ANIMAL
# - My family got a puppy last year.
# - my/mine
# - WANT
# - FAMILY
# - AT-LAST
# - HAVE
# - DSEW(FLAT)-BE:ANIMAL
# - ?LAST-WEEK
# - GOOD
# - A new puppy, it's lovely.
# - NEW
# - DSEW(FLAT)-BE:ANIMAL
# - LOOK-GOOD
# - DSEW(FLAT)-BE:ANIMAL
# - G:WELL
# - My Dad had wanted a dog for a very long time
# - ?LAST-WEEK
# - TRUE
# - my/mine
# - FATHER
# - ALWAYS
# - WANT
# - | WANT
# - WANT
# - | WANT
# - DOG
# - WANT
# - | WANT
# - SINCE
# - Mum had said "no, no, no, no".
# - my/mine
# - MOTHER
# - ALWAYS
# - NO
# - NO
# - NO
# - NO
# - NO
# - FATHER
# - My Dad had been very patient
# - BEHAVIOUR
# - My Sister said to our Mum, "It's not fair, Dad wants a dog"
# - my/mine
# - SISTER
# - SAY
# - NO
# - EQUAL
# - my/mine
# - FATHER
# - WANT
# - DOG
# - G:WELL
# - My Mum still wasn't sure but then things settled down.
# - my/mine
# - MOTHER
# - G:ERM
# - G:WELL
# - SAME
# - SETTLE
# - SETTLE
# - my/mine
# - My sister got married and moved to England.
# - SISTER
# - MARRY
# - MOVE
# - SN:ENGLAND(ROYAL)
# - G:WELL
# - It seemed like the right time to get a dog.
# - WHY
# - NO
# - RIGHT
# - TIME
# - HAVE
# - DOG
# - SAY
# - She said, "alright but there are two things."
# - ALRIGHT
# - DOG
# - BUT
# - TWO
# - (points to list) | LBUOY-TWO
# - (points to list) | LBUOY-TWO
# - Its hair mustn't fall anywhere at all.
# - MUST
# - NOTHING
# - HAIR
# - ?FALL
# - NOTHING
# - Because she didn't want to have to be vacuuming.
# - (points to list) | LBUOY-TWO
# - WHY
# - WANT
# - HOOVER
# - Secondly, it had to be small and not too big.
# - (points to list) | LBUOY-TWO
# - (points to list) | LBUOY-TWO
# - SMALL
# - NOT
# - BIG
# - G:WELL
# - My father said "alright" and started looking.
# - my/mine
# - FATHER
# - He found a Shih Tzu.
# - That's the name of the breed.
# - Their hairs don't fall and they are small, from China.
# - Beautiful.
# - My Dad looked in the newspaper and found a place just outside Ballymena where they breed them.
# - So, we drove over.
# - We met a man, in a shed.
# - He had six puppies, they were lovely.
# - The first dog that came up to us was ours!
# - Because it was the one that came to us first.
# - It came up, we had to take that one home!
# - With me in the back of the car, it was so small and lovely to stroke.
# - It was shy, nervous and tiny.
# - Just eight weeks old and so small.
# - I kept stroking the puppy.
# - We called her Honey.
# - Because her soft coat colour was ...
# - A girl, yes.
# - She had a honey coloured coat, so we called her "Honey".
# - We got home.
# - The first night, in our living room, Honey was under one of the chairs.
# - She looked frightened.
# - I think it was a new house.
# - She stayed hiding under the chair.
# - We tried to coax her out by stroking her.
# - Then she grew in confidence.
# - It has been one year now.
# - She's this big now.
# - She knows that we are Deaf.
# - That's great, because ...
# - If she looks and makes eye contact, we know that she's finished her water and she needs more by the way she looks up at us.
# - You know, to give her more water.
# - or, it's the door and she wants to go outside to the toilet.
# - You know by the look she gives, and I'll open the door.
# - In the living room there's a ledge in front of the window.
# - The dog loves to sit on there, watching outside.
# - She sits, looking up at it, then we lift her up there.
# - Her eye contact is so strong.
# - But with my Dad, she will bark as she knows my Dad can hear her barking.
# - But with my Mum and me, she uses eye contact.
# - It's great that she knows, really clever.
# - It's lovely!
# - She really loves my dad and he is definitely the master.
# - During the day she is fine with my Mum.
# - When my dad arrives home she follows him around everywhere.
# - She knows some signs as well.
# - Signs like: car, walk, food, as well as make up.
# - Every morning my mum goes over and signs "make up" to the dog, she wags her tail and gets all excited!
# - My mum lifts her up onto the table.
# - She lies down and gets brushed and sprayed.
# - It's brilliant!
# - She knows what the sign "make up" means and she wags her tail.
# - She gets brushed every morning.
# - Her coat must be brushed every day.
# - Before this, I never really had any great love of animals.
# - I didn't give them a thought.
# - When we got Honey, I became very attached, it was really lovely.
# - I recently watched a film with Mum and Dad, you know "Lassie"?
# - Well, I felt really emotional, but before, I wouldn't really have cared or paid it any attention.
# - Now, I am really fond of animals, because having a dog has made a difference.
# - She's lovely.
# - It has been one year now.
